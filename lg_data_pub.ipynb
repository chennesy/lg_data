# %% [markdown]
# # Data resources on academic LibGuides
#
# Code used to analyze data for the paper "Taking count: A computational analysis of data resources on academic LibGuides," by Cody Hennesy, Alicia Kubas, and Jenny McBurney (currently being prepared for submission).

# %%
import pandas as pd
import re
import pickle

# %% [markdown]
# ## Import scraped data
# Details about the collection of data from LibGuides is available in the full paper and the code used to scrape the original guides is available upon request (email chennesy@umn.edu).
#
# The data used below is available from the Data Repository for U of M (DRUM). (Link forthcoming)

# %%
#adjust the line below to point to the CSV file that you've downloaded from DRUM.
df_links = pd.read_csv('drum/lg_data.csv')

# %%
df_links.dtypes
# Out:
# resource_name_normalized    object
# resource_name_scraped       object
# resource_url                object
# resource_url_simple         object
# resource_domain             object
# guide_url                   object
# institution_site_id          int64
# dtype: object

# %% [markdown]
# ### Descriptive statistics
#
# #### Number of resources
# "Resources" refers to the links collected from all guides. They include "link assets" and "database assets" (according to the terms used in LibGuides) as well as any other links added in the WYSIWYG tool in LibGuides.

# %%
print('Number of non-unique resources in dataset:', '{:,}'.format(len(df_links)), '\n')
print('Unique resource names',
      '\n----------------------------------------------------------------------',
      '\nUnique resource names, after initial cleaning but before normalization:', df_links['resource_name_scraped'].nunique(), 
      '\nUnique resource names after cleaning and normalization:', df_links['resource_name_normalized'].nunique(), 
     '\nResource names normalized through cleaning:', df_links['resource_name_scraped'].nunique() -  df_links['resource_name_normalized'].nunique(), '('
     '{:.2%}'.format((df_links['resource_name_scraped'].nunique() -  df_links['resource_name_normalized'].nunique())/ df_links['resource_name_scraped'].nunique())+')'
       '\n----------------------------------------------------------------------')
# Out:
# Number of non-unique resources in dataset: 186,952
#
# Unique resource names
# ----------------------------------------------------------------------
# Unique resource names, after initial cleaning but before normalization: 77094
# Unique resource names after cleaning and normalization: 64131
# Resource names normalized through cleaning: 12963 (16.81%)
# ----------------------------------------------------------------------

# %% [markdown]
# #### Number of guide pages

# %%
n_links_per_guide_page = df_links['guide_url'].value_counts()

n_guides = df_links['guide_url'].nunique()
print('Number of guide pages included in study:', n_guides)
# Out:
# Number of guide pages included in study: 10448

# %% [markdown]
# #### Resources per institution

# %%
links_per_site = df_links.groupby('institution_site_id')['resource_name_normalized'].count().sort_values(ascending=False)
unique_links_per_site = df_links.groupby('institution_site_id')['resource_name_normalized'].nunique().sort_values(ascending=False)

print('Number of institutions:',
      df_links['institution_site_id'].nunique(),
     '\n-------------------------------------------------------------\n')

for i, df in enumerate([links_per_site, unique_links_per_site]):
    if i == 0:
        print('Non-unique links per institution:')
    else:
        print('Unique links per institution:')
    print(
      '-------------------------------------------------------------',
      '\nMaximum:', df.max(),
      '\nMinimum:', df.min(),
      '\nMean:', '{:.2f}'.format(df.mean()), 
      '\nStandard deviation', '{:.2f}'.format(df.std()),
     '\n-------------------------------------------------------------')
# Out:
# Number of institutions: 123
# -------------------------------------------------------------
#
# Non-unique links per institution:
# -------------------------------------------------------------
# Maximum: 10799
# Minimum: 21
# Mean: 1519.93
# Standard deviation 1395.24
# -------------------------------------------------------------
# Unique links per institution:
# -------------------------------------------------------------
# Maximum: 3284
# Minimum: 21
# Mean: 791.96
# Standard deviation 638.44
# -------------------------------------------------------------

# %% [markdown]
# #### Guide pages per site

# %%
unique_pages_per_site = df_links.groupby('institution_site_id')['guide_url'].nunique().sort_values(ascending=False)

print('Guide pages per institution:')
print(
  '-------------------------------------------------------------',
  '\nMaximum:', unique_pages_per_site.max(),
  '\nMinimum:', unique_pages_per_site.min(),
  '\nMean:', '{:.2f}'.format(unique_pages_per_site.mean()), 
  '\nStandard deviation', '{:.2f}'.format(unique_pages_per_site.std()),
 '\n-------------------------------------------------------------')
# Out:
# Guide pages per institution:
# -------------------------------------------------------------
# Maximum: 336
# Minimum: 1
# Mean: 84.94
# Standard deviation 64.15
# -------------------------------------------------------------

# %% [markdown]
# ### Top 500 resources
# Creates a link_site_df dataframe containing the 500 most common resources by the 'resource_name_normalized' column.

# %%
#save the top unique resource names to new dataframe
unique_names = df_links['resource_name_normalized'].value_counts()
top_names = unique_names.to_frame()

#unique site_ids to list
site_ids = df_links['institution_site_id'].unique().tolist()

#create empty df to populate with names and site_id counts and
#assign site_ids as column names
link_site_df = pd.DataFrame(columns=site_ids)

#add name column and add top 500 databases as values
link_site_df['name'] = top_names.index[0:500]

#move name column to beginning of df
cols = list(link_site_df.columns)
cols = [cols[-1]] + cols[:-1]
link_site_df = link_site_df[cols]

#set name column as index
link_site_df = link_site_df.set_index(['name'])

#add counts of each resource to df

#add value of 1 if name is found in site_id and 0 if name is not found for site_id
for site in site_ids:
    current_site = df_links[df_links['institution_site_id'] == site]
    for name in top_names.index[0:500]:
        
        matches = current_site[current_site['resource_name_normalized'] == name]
        if len(matches) >= 1:
            link_site_df.loc[name, site] = 1
        else:
            link_site_df.loc[name, site] = 0

#create columns for sum and percent of how many sites include each link name
link_site_df['sum'] = link_site_df.sum(axis=1)
link_site_df['percent'] = link_site_df['sum']/len(site_ids)
link_site_df['percent_of_sites'] = (100. * link_site_df['percent']).round(2).astype(str) + '%'
link_site_df = link_site_df.sort_values(by=['percent'], ascending=False)

#add column with full counts per db
link_site_df['count'] = ''

#add counts for top 500 links to df
for i,row in top_names[0:500].iterrows():
    name = i
    count = row['resource_name_normalized']
    link_site_df.loc[name, 'count'] = count

#add column with an example url that equals the most common (simplified) url found per resource name

#create empty column
link_site_df['url'] = ''

#for each link in top_names, create a subset dataframe and then count the most common simple urls
#then add the simple url next to the appropriate row in link_site_df

for i,row in top_names[0:500].iterrows():
    name = i
    current_site = df_links[df_links['resource_name_normalized'] == i]
    most_common_url = current_site['resource_url_simple'].value_counts()
    mc_url = most_common_url.index[0]
    link_site_df.loc[name, 'url'] = mc_url

link_site_df.reset_index(inplace=True)

# %% [markdown]
# At this stage the 'name', 'sum', 'percent_of_sites', 'count', and 'url' columns were exported to CSV and added to a Google Sheet where co-authors annotated the sheet to note whether each of the top resources was a 'free', 'paid', or 'hybrid' resource.

# %% [markdown]
# ### Top 20 Resources (Sorted by percentage)
# Table of the twenty resources most commonly included across institutional sites.

# %%
table_top_resources = link_site_df[['name','percent_of_sites', 'count', 'url']][0:20]
table_top_resources = table_top_resources.rename(columns ={'name': 'Resource name', 'percent_of_sites':'Percentage of institutions', 'count':'Overall count', 'url':'Example URL'})
table_top_resources
# Out:
#                                         Resource name  \
# 0                                               icpsr
# 1                                            data.gov
# 2                                  u.s. census bureau
# 3                                   u.s. census: data
# 4                             undata (united nations)
# 5   nces (u.s. national center for education stati...
# 6   nchs (u.s. national center for health statistics)
# 7                    u.s. census: american factfinder
# 8               bls (u.s. bureau of labor statistics)
# 9                                 roper center: ipoll
# 10                     eurostat (european commission)
# 11            bjs (u.s. bureau of justice statistics)
# 12                                    social explorer
# 13  who: global health observatory (world health o...
# 14  statistical abstract of the united states (pro...
# 15                                   world bank: data
# 16  historical statistics of the united states (ca...
# 17             bea (u.s. bureau of economic analysis)
# 18             imf data (international monetary fund)
# 19                           cdc: data and statistics
#
#    Percentage of institutions Overall count  \
# 0                      94.31%          1834
# 1                      94.31%           954
# 2                       93.5%           956
# 3                      90.24%          1145
# 4                      88.62%          1054
# 5                      86.99%           546
# 6                      86.99%           856
# 7                      83.74%           720
# 8                      82.93%           535
# 9                      80.49%          1090
# 10                     80.49%           501
# 11                     78.86%           437
# 12                     78.86%          1430
# 13                     78.05%           491
# 14                     78.05%          1058
# 15                     76.42%           545
# 16                      74.8%           684
# 17                      74.8%           422
# 18                      74.8%           445
# 19                     73.17%           361
#
#                                           Example URL
# 0                                 www.icpsr.umich.edu
# 1                                        www.data.gov
# 2                                      www.census.gov
# 3                              data.census.gov/cedsci
# 4                                         data.un.org
# 5                                         nces.ed.gov
# 6                                    www.cdc.gov/nchs
# 7   factfinder.census.gov/faces/nav/jsf/pages/inde...
# 8                                         www.bls.gov
# 9   proxy2.library.illinois.edu/login?url=ropercen...
# 10                              ec.europa.eu/eurostat
# 11                                        www.bjs.gov
# 12                             www.socialexplorer.com
# 13                                 www.who.int/gho/en
# 14         www.libraries.rutgers.edu/indexes/statabus
# 15                                 data.worldbank.org
# 16                         hsus.cambridge.org/HSUSWeb
# 17                                        www.bea.gov
# 18                                       data.imf.org
# 19                         www.cdc.gov/DataStatistics

# %% [markdown]
# ### Top 10 Resources (Sorted by overall count)

# %%
top_10 = link_site_df[['name','percent_of_sites', 'count', 'url']].sort_values(by='count', ascending=False)[0:10]
top_10
# Out:
#                                                  name percent_of_sites count  \
# 0                                               icpsr           94.31%  1834
# 31                     statistical insight (proquest)           61.79%  1532
# 12                                    social explorer           78.86%  1430
# 53                                 data planet (sage)           50.41%  1318
# 3                                   u.s. census: data           90.24%  1145
# 28                                           statista           64.23%  1104
# 9                                 roper center: ipoll           80.49%  1090
# 14  statistical abstract of the united states (pro...           78.05%  1058
# 4                             undata (united nations)           88.62%  1054
# 2                                  u.s. census bureau            93.5%   956
#
#                                                   url
# 0                                 www.icpsr.umich.edu
# 31  proxy2.library.illinois.edu/login?url=search.p...
# 12                             www.socialexplorer.com
# 53  go.openathens.net/redirector/fiu.edu?url=datap...
# 3                              data.census.gov/cedsci
# 28  go.openathens.net/redirector/fiu.edu?url=http%...
# 9   proxy2.library.illinois.edu/login?url=ropercen...
# 14         www.libraries.rutgers.edu/indexes/statabus
# 4                                         data.un.org
# 2                                      www.census.gov

# %% [markdown]
# ### Top 10 (full) Domains

# %%
unique_domain_counts = df_links['resource_domain'].value_counts()
domains_top = unique_domain_counts.to_frame()
domains_top = domains_top.reset_index()
domains_top = domains_top.rename(columns = {'index': 'Domain', 'domain': 'Count'})
domains_top[0:10]
# Out:
#                         Domain  resource_domain
# 0                   census.gov             7656
# 1                      cdc.gov             5382
# 2                  nces.ed.gov             2546
# 3              icpsr.umich.edu             2222
# 4                      bls.gov             1928
# 5            go.openathens.net             1837
# 6                      who.int             1202
# 7  utk.primo.exlibrisgroup.com             1128
# 8           data.worldbank.org             1120
# 9              nrs.harvard.edu             1120

# %% [markdown]
# ### Top 20 Root Domains
# Note that root domains such as harvard.edu, exlibrisgroup.com, upenn.edu, cornell.edu, openathens.net, and msu.edu are not included in the final paper Table since the most common resources included from those domains were not relevant to our analysis. See full output below for example subdomains for each.

# %%
#separate the top level domain (this is slightly coarse but works for the top sites)
df_links['top_level_domain'] = df_links.resource_domain.str.split(r'([^.\s]+\.[^.\s]+)$').str[1]
top_level_domain_counts = df_links['top_level_domain'].value_counts()

root_domains_top = top_level_domain_counts.to_frame()
root_domains_top = root_domains_top.reset_index()
root_domains_top = root_domains_top.rename(columns = {'index': 'Root domain', 'top_level_domain': 'Count'})
root_domains_top[0:20]
# Out:
#           Root domain  Count
# 0          census.gov   9670
# 1             cdc.gov   6072
# 2         harvard.edu   4480
# 3           umich.edu   3691
# 4              ed.gov   3122
# 5   exlibrisgroup.com   2744
# 6       worldbank.org   2705
# 7              un.org   2636
# 8           upenn.edu   2319
# 9         cornell.edu   2155
# 10            bls.gov   2066
# 11     openathens.net   1861
# 12           usda.gov   1853
# 13            nih.gov   1570
# 14            msu.edu   1421
# 15            who.int   1411
# 16      princeton.edu   1347
# 17           data.gov   1242
# 18           oclc.org   1240
# 19            unc.edu   1238

# %% [markdown]
# #### Print the ten most common domains for each of the top 20 root domains

# %%
root_domains_20 = {}
for i, row in root_domains_top[0:50].iterrows():
    root_domains_20[row['Root domain']] = row['Count']

for k,v in root_domains_20.items():
    domain_check = domains_top[domains_top['Domain'].str.contains(k)]
    print(k, '\n------------------------------------------------\n',
          k, 'total count:', v, '\n', 
          k, '# of domains:', len(domain_check), '\n',
          k, 'mean count per domain:', '{:.2f}'.format(v/len(domain_check)), '\n\n', 
          domain_check[0:10],
         '\n------------------------------------------------\n')
# Out:
# census.gov
# ------------------------------------------------
#  census.gov total count: 9670
#  census.gov # of domains: 42
#  census.gov mean count per domain: 230.24
#
#                        Domain  resource_domain
# 0                 census.gov             7656
# 14           data.census.gov              945
# 64     factfinder.census.gov              343
# 75    factfinder2.census.gov              316
# 466   dataferrett.census.gov               61
# 626      usatrade.census.gov               45
# 674      lehd.ces.census.gov               41
# 680    quickfacts.census.gov               41
# 814           ask.census.gov               33
# 965  onthemap.ces.census.gov               27
# ------------------------------------------------
#
# cdc.gov
# ------------------------------------------------
#  cdc.gov total count: 6072
#  cdc.gov # of domains: 26
#  cdc.gov mean count per domain: 233.54
#
#                               Domain  resource_domain
# 1                           cdc.gov             5382
# 65                   wonder.cdc.gov              341
# 335                    wwwn.cdc.gov               83
# 414                    data.cdc.gov               68
# 757                   atsdr.cdc.gov               36
# 787             chronicdata.cdc.gov               34
# 793                    nccd.cdc.gov               34
# 1588  www-cdc-gov.proxy.lib.fsu.edu               15
# 1737                    svi.cdc.gov               14
# 2537            ephtracking.cdc.gov                9
# ------------------------------------------------
#
# harvard.edu
# ------------------------------------------------
#  harvard.edu total count: 4480
#  harvard.edu # of domains: 243
#  harvard.edu mean count per domain: 18.44
#
#                                         Domain  resource_domain
# 9                             nrs.harvard.edu             1120
# 11                         id.lib.harvard.edu             1069
# 33                      dataverse.harvard.edu              478
# 49                 guides.library.harvard.edu              382
# 225                        hollis.harvard.edu              123
# 416                       library.harvard.edu               68
# 429                          wiki.harvard.edu               67
# 542                   projects.iq.harvard.edu               51
# 564  heinonline.org.ezp-prod1.hul.harvard.edu               50
# 631                           law.harvard.edu               45
# ------------------------------------------------
#
# umich.edu
# ------------------------------------------------
#  umich.edu total count: 3691
#  umich.edu # of domains: 91
#  umich.edu mean count per domain: 40.56
#
#                                    Domain  resource_domain
# 3                        icpsr.umich.edu             2222
# 45                         lib.umich.edu              395
# 78                  guides.lib.umich.edu              304
# 110                   apps.lib.umich.edu              239
# 207                 search.lib.umich.edu              133
# 411             psidonline.isr.umich.edu               69
# 513                  proxy.lib.umich.edu               54
# 552   www-icpsr-umich-edu.ezproxy.bu.edu               51
# 709              hrsonline.isr.umich.edu               39
# 1084                       law.umich.edu               24
# ------------------------------------------------
#
# ed.gov
# ------------------------------------------------
#  ed.gov total count: 3122
#  ed.gov # of domains: 31
#  ed.gov mean count per domain: 100.71
#
#                         Domain  resource_domain
# 2                 nces.ed.gov             2546
# 158                    ed.gov              184
# 260                ope.ed.gov              109
# 433                ies.ed.gov               66
# 517      eddataexpress.ed.gov               54
# 711            ocrdata.ed.gov               39
# 782   collegescorecard.ed.gov               34
# 840          dashboard.ed.gov               32
# 1427              eric.ed.gov               17
# 2198            p12.nysed.gov               11
# ------------------------------------------------
#
# exlibrisgroup.com
# ------------------------------------------------
#  exlibrisgroup.com total count: 2744
#  exlibrisgroup.com # of domains: 74
#  exlibrisgroup.com mean count per domain: 37.08
#
#                                               Domain  resource_domain
# 7                       utk.primo.exlibrisgroup.com             1128
# 228  galileo-usg-gsu-primo.hosted.exlibrisgroup.com              122
# 233                    pitt.primo.exlibrisgroup.com              120
# 238             i-share-uiu.primo.exlibrisgroup.com              119
# 268         alliance-primo.hosted.exlibrisgroup.com              106
# 322               ou-primo.hosted.exlibrisgroup.com               87
# 347               bc-primo.hosted.exlibrisgroup.com               80
# 383          pascal-clemson.primo.exlibrisgroup.com               72
# 421                buprimo.hosted.exlibrisgroup.com               68
# 505         utah-primoprod.hosted.exlibrisgroup.com               55
# ------------------------------------------------
#
# worldbank.org
# ------------------------------------------------
#  worldbank.org total count: 2705
#  worldbank.org # of domains: 56
#  worldbank.org mean count per domain: 48.30
#
#                            Domain  resource_domain
# 8             data.worldbank.org             1120
# 41        databank.worldbank.org              423
# 125     datatopics.worldbank.org              220
# 136                worldbank.org              205
# 137    datacatalog.worldbank.org              205
# 271            web.worldbank.org              106
# 561  openknowledge.worldbank.org               50
# 571      microdata.worldbank.org               50
# 594             go.worldbank.org               48
# 610           econ.worldbank.org               46
# ------------------------------------------------
#
# un.org
# ------------------------------------------------
#  un.org total count: 2636
#  un.org # of domains: 40
#  un.org mean count per domain: 65.90
#
#                       Domain  resource_domain
# 10           unstats.un.org             1076
# 13              data.un.org              977
# 131                  un.org              214
# 190         comtrade.un.org              154
# 736             mdgs.un.org               37
# 784              esa.un.org               34
# 1295       dataunodc.un.org               19
# 1447  digitallibrary.un.org               17
# 1735        research.un.org               14
# 1857         library.un.org               13
# ------------------------------------------------
#
# upenn.edu
# ------------------------------------------------
#  upenn.edu total count: 2319
#  upenn.edu # of domains: 54
#  upenn.edu mean count per domain: 42.94
#
#                            Domain  resource_domain
# 15         hdl.library.upenn.edu              882
# 80       proxy.library.upenn.edu              300
# 107     guides.library.upenn.edu              245
# 114   franklin.library.upenn.edu              235
# 127   wrds-www.wharton.upenn.edu              218
# 144   wrds-web.wharton.upenn.edu              197
# 460       wrds.wharton.upenn.edu               63
# 1262       dla.library.upenn.edu               20
# 1308       catalog.ldc.upenn.edu               19
# 1421               ldc.upenn.edu               18
# ------------------------------------------------
#
# cornell.edu
# ------------------------------------------------
#  cornell.edu total count: 2155
#  cornell.edu # of domains: 86
#  cornell.edu mean count per domain: 25.06
#
#                               Domain  resource_domain
# 19       guides.library.cornell.edu              661
# 51     resolver.library.cornell.edu              380
# 73         usda.mannlib.cornell.edu              320
# 134         ropercenter.cornell.edu              208
# 203  newcatalog.library.cornell.edu              140
# 515               ciser.cornell.edu               54
# 609              ndacan.cornell.edu               46
# 613        usda.library.cornell.edu               46
# 703                 law.cornell.edu               40
# 887       archive.ciser.cornell.edu               30
# ------------------------------------------------
#
# bls.gov
# ------------------------------------------------
#  bls.gov total count: 2066
#  bls.gov # of domains: 4
#  bls.gov mean count per domain: 516.50
#
#               Domain  resource_domain
# 4           bls.gov             1928
# 232   stats.bls.gov              121
# 1997   data.bls.gov               12
# 4190   beta.bls.gov                5
# ------------------------------------------------
#
# openathens.net
# ------------------------------------------------
#  openathens.net total count: 1861
#  openathens.net # of domains: 8
#  openathens.net mean count per domain: 232.62
#
#                                                    Domain  resource_domain
# 5                                      go.openathens.net             1837
# 1863                              connect.openathens.net               13
# 6524        www-icpsr-umich-edu.eu1.proxy.openathens.net                3
# 8343    app-simplyanalytics-com.eu1.proxy.openathens.net                2
# 8660   statisticaldatasets-data--planet-com.eu1.proxy...                2
# 9950    ropercenter-cornell-edu.eu1.proxy.openathens.net                2
# 12409        www-ccdc-cam-ac-uk.eu1.proxy.openathens.net                1
# 18576              www-rkma-com.eu1.proxy.openathens.net                1
# ------------------------------------------------
#
# usda.gov
# ------------------------------------------------
#  usda.gov total count: 1853
#  usda.gov # of domains: 69
#  usda.gov mean count per domain: 26.86
#
#                          Domain  resource_domain
# 26               nass.usda.gov              530
# 67                ers.usda.gov              329
# 183          agcensus.usda.gov              165
# 258               fas.usda.gov              110
# 280  datagateway.nrcs.usda.gov              103
# 340                   usda.gov               82
# 458               ars.usda.gov               63
# 493               fns.usda.gov               57
# 590              nrcs.usda.gov               48
# 776               nal.usda.gov               35
# ------------------------------------------------
#
# nih.gov
# ------------------------------------------------
#  nih.gov total count: 1570
#  nih.gov # of domains: 117
#  nih.gov mean count per domain: 13.42
#
#                          Domain  resource_domain
# 34            ncbi.nlm.nih.gov              477
# 47                 nlm.nih.gov              392
# 226               nimh.nih.gov              123
# 596   pubchem.ncbi.nlm.nih.gov               47
# 683          hsric.nlm.nih.gov               41
# 734                    nih.gov               37
# 836              niddk.nih.gov               32
# 875          wwwcf.nlm.nih.gov               30
# 1132        toxnet.nlm.nih.gov               23
# 1181            grants.nih.gov               22
# ------------------------------------------------
#
# msu.edu
# ------------------------------------------------
#  msu.edu total count: 1421
#  msu.edu # of domains: 78
#  msu.edu mean count per domain: 18.22
#
#                       Domain  resource_domain
# 52      catalog.lib.msu.edu              379
# 85          ezproxy.msu.edu              288
# 117     archive.lib.msu.edu              234
# 129   libguides.lib.msu.edu              214
# 358      globaledge.msu.edu               77
# 789           ippsr.msu.edu               34
# 1020         er.lib.msu.edu               26
# 1137            lib.msu.edu               23
# 2035            opb.msu.edu               11
# 2607      staff.lib.msu.edu                9
# ------------------------------------------------
#
# who.int
# ------------------------------------------------
#  who.int total count: 1411
#  who.int # of domains: 14
#  who.int mean count per domain: 100.79
#
#                      Domain  resource_domain
# 6                  who.int             1202
# 182           apps.who.int              168
# 2007          euro.who.int               12
# 2912   gamapserver.who.int                7
# 3053       covid19.who.int                7
# 4952          www3.who.int                4
# 6074          afro.who.int                3
# 7278      rho.emro.who.int                2
# 11891     extranet.who.int                1
# 12871         iarc.who.int                1
# ------------------------------------------------
#
# princeton.edu
# ------------------------------------------------
#  princeton.edu total count: 1347
#  princeton.edu # of domains: 46
#  princeton.edu mean count per domain: 29.28
#
#                                           Domain  resource_domain
# 31                        library.princeton.edu              481
# 118                     libguides.princeton.edu              233
# 188                       catalog.princeton.edu              155
# 514                           opr.princeton.edu               54
# 578                   faq.library.princeton.edu               49
# 689                  mediacentral.princeton.edu               41
# 753                       mmp.opr.princeton.edu               36
# 764                          dss2.princeton.edu               35
# 1028                     popindex.princeton.edu               26
# 1060  methods-sagepub-com.ezproxy.princeton.edu               25
# ------------------------------------------------
#
# data.gov
# ------------------------------------------------
#  data.gov total count: 1242
#  data.gov # of domains: 52
#  data.gov mean count per domain: 23.88
#
#                  Domain  resource_domain
# 12            data.gov             1032
# 143     healthdata.gov              198
# 162   catalog.data.gov              183
# 702        data.gov.uk               40
# 1442       data.gov.au               17
# 1681       data.gov.in               14
# 2645      geo.data.gov                8
# 3123   health.data.gov                7
# 4330       data.gov.ua                4
# 4569  gos2.geodata.gov                4
# ------------------------------------------------
#
# oclc.org
# ------------------------------------------------
#  oclc.org total count: 1240
#  oclc.org # of domains: 48
#  oclc.org mean count per domain: 25.83
#
#                        Domain  resource_domain
# 53          cmu.idm.oclc.org              375
# 123          uc.idm.oclc.org              224
# 139        pitt.idm.oclc.org              200
# 196        yale.idm.oclc.org              147
# 263         unh.idm.oclc.org              108
# 937   dartmouth.idm.oclc.org               28
# 1096        wvu.idm.oclc.org               24
# 1538                oclc.org               16
# 1564   colorado.idm.oclc.org               16
# 1715       utep.idm.oclc.org               14
# ------------------------------------------------
#
# unc.edu
# ------------------------------------------------
#  unc.edu total count: 1238
#  unc.edu # of domains: 81
#  unc.edu mean count per domain: 15.28
#
#                       Domain  resource_domain
# 25       guides.lib.unc.edu              547
# 283     catalog.lib.unc.edu              102
# 407       dataverse.unc.edu               69
# 422         library.unc.edu               67
# 476    libproxy.lib.unc.edu               60
# 481             cpc.unc.edu               59
# 684        arc.irss.unc.edu               41
# 893            odum.unc.edu               30
# 1291           irss.unc.edu               20
# 1408  garymarks.web.unc.edu               18
# ------------------------------------------------
#
# europa.eu
# ------------------------------------------------
#  europa.eu total count: 1233
#  europa.eu # of domains: 52
#  europa.eu mean count per domain: 23.71
#
#                           Domain  resource_domain
# 17                 ec.europa.eu              766
# 227   epp.eurostat.ec.europa.eu              122
# 496              data.europa.eu               57
# 511                   europa.eu               55
# 642               eea.europa.eu               44
# 936          eacea.ec.europa.eu               28
# 1904          eur-lex.europa.eu               12
# 1995             ecdc.europa.eu               12
# 2092            curia.europa.eu               11
# 2241              ecb.europa.eu               10
# ------------------------------------------------
#
# google.com
# ------------------------------------------------
#  google.com total count: 1190
#  google.com # of domains: 32
#  google.com mean count per domain: 37.19
#
#                                   Domain  resource_domain
# 32                           google.com              481
# 157                  toolbox.google.com              185
# 296                     docs.google.com               97
# 401   datasetsearch.research.google.com               70
# 474                    drive.google.com               60
# 486                    sites.google.com               59
# 544                  support.google.com               51
# 713                    books.google.com               39
# 716                  scholar.google.com               38
# 1174                    maps.google.com               22
# ------------------------------------------------
#
# missouri.edu
# ------------------------------------------------
#  missouri.edu total count: 1183
#  missouri.edu # of domains: 39
#  missouri.edu mean count per domain: 30.33
#
#                            Domain  resource_domain
# 24       laurel.lso.missouri.edu              549
# 133   libraryguides.missouri.edu              211
# 236       proxy.mul.missouri.edu              119
# 332            mcdc.missouri.edu               85
# 386         library.missouri.edu               72
# 1027          mcdc2.missouri.edu               26
# 1321          msdis.missouri.edu               19
# 1889          oseda.missouri.edu               13
# 2428         census.missouri.edu                9
# 2632         mobius.missouri.edu                8
# ------------------------------------------------
#
# usgs.gov
# ------------------------------------------------
#  usgs.gov total count: 1148
#  usgs.gov # of domains: 100
#  usgs.gov mean count per domain: 11.48
#
#                        Domain  resource_domain
# 71                  usgs.gov              323
# 264   earthexplorer.usgs.gov              108
# 338           ngmdb.usgs.gov               83
# 436           water.usgs.gov               65
# 477         pubs.er.usgs.gov               60
# 484            pubs.usgs.gov               59
# 708       waterdata.usgs.gov               39
# 802            eros.usgs.gov               33
# 1023         energy.usgs.gov               26
# 1280      landcover.usgs.gov               20
# ------------------------------------------------
#
# berkeley.edu
# ------------------------------------------------
#  berkeley.edu total count: 1118
#  berkeley.edu # of domains: 67
#  berkeley.edu mean count per domain: 16.69
#
#                             Domain  resource_domain
# 38          libproxy.berkeley.edu              440
# 148       guides.lib.berkeley.edu              191
# 275          oskicat.berkeley.edu              104
# 352              sda.berkeley.edu               79
# 501              lib.berkeley.edu               56
# 688   search.library.berkeley.edu               41
# 902             dlab.berkeley.edu               29
# 1600             gif.berkeley.edu               15
# 1613          ucdata.berkeley.edu               15
# 1700    researchdata.berkeley.edu               14
# ------------------------------------------------
#
# arcgis.com
# ------------------------------------------------
#  arcgis.com total count: 1109
#  arcgis.com # of domains: 273
#  arcgis.com mean count per domain: 4.06
#
#                                       Domain  resource_domain
# 189                              arcgis.com              154
# 562                      desktop.arcgis.com               50
# 623                  livingatlas.arcgis.com               45
# 845                          hub.arcgis.com               31
# 955                    storymaps.arcgis.com               28
# 1000  hifld-geoplatform.opendata.arcgis.com               26
# 1089                         bao.arcgis.com               24
# 1221            communityanalyst.arcgis.com               21
# 1390               yalemaps.maps.arcgis.com               18
# 1480          gis-txdot.opendata.arcgis.com               17
# ------------------------------------------------
#
# bu.edu
# ------------------------------------------------
#  bu.edu total count: 1104
#  bu.edu # of domains: 40
#  bu.edu mean count per domain: 27.60
#
#                                      Domain  resource_domain
# 16                          library.bu.edu              862
# 343                                 bu.edu               81
# 552     www-icpsr-umich-edu.ezproxy.bu.edu               51
# 1151               lawlibraryguides.bu.edu               22
# 1622                           bumc.bu.edu               15
# 2957        icpsr.umich.edu.ezproxy.bu.edu                7
# 3972                           open.bu.edu                5
# 4043      link-springer-com.ezproxy.bu.edu                5
# 4773                           math.bu.edu                4
# 4787  oxfordscholarship.com.ezproxy.bu.edu                4
# ------------------------------------------------
#
# wisc.edu
# ------------------------------------------------
#  wisc.edu total count: 1104
#  wisc.edu # of domains: 64
#  wisc.edu mean count per domain: 17.25
#
#                                 Domain  resource_domain
# 43    researchguides.library.wisc.edu              415
# 145           search.library.wisc.edu              195
# 167          digital.library.wisc.edu              178
# 570                      ssc.wisc.edu               50
# 611                     disc.wisc.edu               46
# 872                  library.wisc.edu               30
# 1039                     irp.wisc.edu               25
# 1423                     sco.wisc.edu               18
# 1734                  nelson.wisc.edu               14
# 2006               dpls.dacc.wisc.edu               12
# ------------------------------------------------
#
# illinois.edu
# ------------------------------------------------
#  illinois.edu total count: 984
#  illinois.edu # of domains: 60
#  illinois.edu mean count per domain: 16.40
#
#                                 Domain  resource_domain
# 27        proxy2.library.illinois.edu              514
# 191              library.illinois.edu              152
# 355       guides.library.illinois.edu               78
# 843                 stat.illinois.edu               31
# 1256    archives.library.illinois.edu               20
# 1445         clinecenter.illinois.edu               17
# 1845           sfx.carli.illinois.edu               13
# 1877                isws.illinois.edu               13
# 2186     search.grainger.illinois.edu               11
# 2271  clearinghouse.isgs.illinois.edu               10
# ------------------------------------------------
#
# nyu.edu
# ------------------------------------------------
#  nyu.edu total count: 945
#  nyu.edu # of domains: 37
#  nyu.edu mean count per domain: 25.54
#
#                            Domain  resource_domain
# 35    persistent.library.nyu.edu              461
# 105               guides.nyu.edu              246
# 434       bobcat.library.nyu.edu               66
# 998        getit.library.nyu.edu               27
# 1068             library.nyu.edu               24
# 1097       proxy.library.nyu.edu               23
# 1101        arch.library.nyu.edu               23
# 2008                 law.nyu.edu               12
# 2343     datacatalog.med.nyu.edu               10
# 2556                 geo.nyu.edu                9
# ------------------------------------------------
#
# noaa.gov
# ------------------------------------------------
#  noaa.gov total count: 886
#  noaa.gov # of domains: 74
#  noaa.gov mean count per domain: 11.97
#
#                         Domain  resource_domain
# 82              ncdc.noaa.gov              297
# 214             ngdc.noaa.gov              128
# 427            coast.noaa.gov               67
# 777             nodc.noaa.gov               35
# 829                  noaa.gov               32
# 1015            ncei.noaa.gov               26
# 1159             nws.noaa.gov               22
# 1274  nauticalcharts.noaa.gov               20
# 1316       maps.ngdc.noaa.gov               19
# 1484             nhc.noaa.gov               17
# ------------------------------------------------
#
# ucf.edu
# ------------------------------------------------
#  ucf.edu total count: 877
#  ucf.edu # of domains: 47
#  ucf.edu mean count per domain: 18.66
#
#                               Domain  resource_domain
# 22                   guides.ucf.edu              595
# 279                 library.ucf.edu              104
# 620           stars.library.ucf.edu               46
# 1149                  ucftv.ucf.edu               22
# 2279                    ikm.ucf.edu               10
# 2283                 police.ucf.edu               10
# 2977  login.ezproxy.library.ucf.edu                7
# 2992                     fp.ucf.edu                7
# 4450          libguides.lib.ucf.edu                4
# 4453               graduate.ucf.edu                4
# ------------------------------------------------
#
# utexas.edu
# ------------------------------------------------
#  utexas.edu total count: 874
#  utexas.edu # of domains: 50
#  utexas.edu mean count per domain: 17.48
#
#                        Domain  resource_domain
# 37     guides.lib.utexas.edu              453
# 330           lib.utexas.edu               85
# 478         lanic.utexas.edu               60
# 693          stat.utexas.edu               40
# 712    search.lib.utexas.edu               39
# 1107  ezproxy.lib.utexas.edu               23
# 1220  catalog.lib.utexas.edu               21
# 1494   legacy.lib.utexas.edu               16
# 1693     utip.gov.utexas.edu               14
# 1888      utlists.utexas.edu               13
# ------------------------------------------------
#
# ucla.edu
# ------------------------------------------------
#  ucla.edu total count: 867
#  ucla.edu # of domains: 66
#  ucla.edu mean count per domain: 13.14
#
#                                Domain  resource_domain
# 108          search.library.ucla.edu              244
# 147          guides.library.ucla.edu              192
# 356                 library.ucla.edu               78
# 403         catalog.library.ucla.edu               70
# 804   williamsinstitute.law.ucla.edu               33
# 810                anderson.ucla.edu               33
# 1047                     it.ucla.edu               25
# 1115             stats.idre.ucla.edu               23
# 1456           healthpolicy.ucla.edu               17
# 1540                   heri.ucla.edu               16
# ------------------------------------------------
#
# libguides.com
# ------------------------------------------------
#  libguides.com total count: 867
#  libguides.com # of domains: 57
#  libguides.com mean count per domain: 15.21
#
#                             Domain  resource_domain
# 77             uark.libguides.com              305
# 115            ucsd.libguides.com              235
# 381     data-planet.libguides.com               72
# 607   instr.iastate.libguides.com               47
# 962          godort.libguides.com               27
# 1037        clemson.libguides.com               25
# 1273       proquest.libguides.com               20
# 1306           pitt.libguides.com               19
# 1789           tamu.libguides.com               13
# 2233           uiuc.libguides.com               10
# ------------------------------------------------
#
# vt.edu
# ------------------------------------------------
#  vt.edu total count: 862
#  vt.edu # of domains: 75
#  vt.edu mean count per domain: 11.49
#
#                                     Domain  resource_domain
# 30                      guides.lib.vt.edu              485
# 830                            lib.vt.edu               32
# 851   vt-policymap-com.ezproxy.lib.vt.edu               31
# 1248                      data.lib.vt.edu               20
# 1369            informaticslab.lib.vt.edu               18
# 1392                vtechworks.lib.vt.edu               18
# 1523                           gis.vt.edu               16
# 1844           eiu.com.ezproxy.lib.vt.edu               13
# 1848                  app.nli.tlos.vt.edu               13
# 1861                   catalog.lib.vt.edu               13
# ------------------------------------------------
#
# gmu.edu
# ------------------------------------------------
#  gmu.edu total count: 831
#  gmu.edu # of domains: 57
#  gmu.edu mean count per domain: 14.58
#
#                       Domain  resource_domain
# 62       infoguides.gmu.edu              345
# 84            mutex.gmu.edu              292
# 939    dataservices.gmu.edu               28
# 1228    nassgeodata.gmu.edu               21
# 1255          magik.gmu.edu               20
# 1366  writingcenter.gmu.edu               18
# 1849        library.gmu.edu               13
# 2926          schar.gmu.edu                7
# 3180            its.gmu.edu                7
# 3279        infowiz.gmu.edu                6
# ------------------------------------------------
#
# rutgers.edu
# ------------------------------------------------
#  rutgers.edu total count: 829
#  rutgers.edu # of domains: 53
#  rutgers.edu mean count per domain: 15.64
#
#                                   Domain  resource_domain
# 44                libraries.rutgers.edu              405
# 205               libguides.rutgers.edu              136
# 695                    cawp.rutgers.edu               40
# 856                     scc.rutgers.edu               31
# 867   login.proxy.libraries.rutgers.edu               30
# 1030                  oirap.rutgers.edu               26
# 1406  quicksearch.libraries.rutgers.edu               18
# 1608              ndbserver.rutgers.edu               15
# 2001             njdatabook.rutgers.edu               12
# 2037      catalog.libraries.rutgers.edu               11
# ------------------------------------------------
#
# uchicago.edu
# ------------------------------------------------
#  uchicago.edu total count: 827
#  uchicago.edu # of domains: 46
#  uchicago.edu mean count per domain: 17.98
#
#                          Domain  resource_domain
# 42            lib.uchicago.edu              421
# 221    guides.lib.uchicago.edu              124
# 276        pi.lib.uchicago.edu              104
# 1050         dsal.uchicago.edu               25
# 1249         norc.uchicago.edu               20
# 1534        proxy.uchicago.edu               16
# 1725  catalog.lib.uchicago.edu               14
# 1939      rcc.lib.uchicago.edu               12
# 2496    popcenter.uchicago.edu                9
# 2693    knowledge.uchicago.edu                8
# ------------------------------------------------
#
# virginia.edu
# ------------------------------------------------
#  virginia.edu total count: 818
#  virginia.edu # of domains: 36
#  virginia.edu mean count per domain: 22.72
#
#                            Domain  resource_domain
# 106     proxy01.its.virginia.edu              246
# 132       proxy.its.virginia.edu              213
# 360   mapserver.lib.virginia.edu               77
# 378      guides.lib.virginia.edu               73
# 523      search.lib.virginia.edu               53
# 733      fisher.lib.virginia.edu               37
# 823             lib.virginia.edu               32
# 1104        lib.law.virginia.edu               23
# 1782        library.virginia.edu               13
# 3250   data.library.virginia.edu                6
# ------------------------------------------------
#
# usc.edu
# ------------------------------------------------
#  usc.edu total count: 782
#  usc.edu # of domains: 34
#  usc.edu mean count per domain: 23.00
#
#                        Domain  resource_domain
# 28          libproxy.usc.edu              502
# 171        libguides.usc.edu              177
# 1323         spatial.usc.edu               19
# 1548                 usc.edu               16
# 1641         library.usc.edu               15
# 2713       libraries.usc.edu                8
# 3791        ida.loni.usc.edu                5
# 4474        dornsife.usc.edu                4
# 5116        software.usc.edu                3
# 5145  digitallibrary.usc.edu                3
# ------------------------------------------------
#
# bea.gov
# ------------------------------------------------
#  bea.gov total count: 780
#  bea.gov # of domains: 2
#  bea.gov mean count per domain: 390.00
#
#              Domain  resource_domain
# 18         bea.gov              760
# 1281  apps.bea.gov               20
# ------------------------------------------------
#
# georgetown.edu
# ------------------------------------------------
#  georgetown.edu total count: 761
#  georgetown.edu # of domains: 38
#  georgetown.edu mean count per domain: 20.03
#
#                                    Domain  resource_domain
# 50         guides.library.georgetown.edu              380
# 161         proxy.library.georgetown.edu              183
# 437               library.georgetown.edu               65
# 767       catalog.library.georgetown.edu               35
# 1114                 pdba.georgetown.edu               23
# 2081              faculty.georgetown.edu               11
# 3120                 cara.georgetown.edu                7
# 3211                  uis.georgetown.edu                6
# 3239  findingaids.library.georgetown.edu                6
# 3570            guides.ll.georgetown.edu                6
# ------------------------------------------------
#
# ipums.org
# ------------------------------------------------
#  ipums.org total count: 751
#  ipums.org # of domains: 14
#  ipums.org mean count per domain: 53.64
#
#                         Domain  resource_domain
# 98                  ipums.org              265
# 113             usa.ipums.org              237
# 218   international.ipums.org              126
# 410             cps.ipums.org               69
# 1989           nhis.ipums.org               12
# 2214          terra.ipums.org               11
# 2417  healthsurveys.ipums.org                9
# 3419       highered.ipums.org                6
# 4223          ihgis.ipums.org                5
# 4237           meps.ipums.org                4
# ------------------------------------------------
#
# ahrq.gov
# ------------------------------------------------
#  ahrq.gov total count: 734
#  ahrq.gov # of domains: 15
#  ahrq.gov mean count per domain: 48.93
#
#                              Domain  resource_domain
# 60                        ahrq.gov              348
# 224               hcupnet.ahrq.gov              123
# 278                  meps.ahrq.gov              104
# 473               hcup-us.ahrq.gov               60
# 656               nhqrnet.ahrq.gov               43
# 1594                cahps.ahrq.gov               15
# 2420  effectivehealthcare.ahrq.gov                9
# 3071          innovations.ahrq.gov                7
# 3084      qualitymeasures.ahrq.gov                7
# 3159              archive.ahrq.gov                7
# ------------------------------------------------
#
# ac.uk
# ------------------------------------------------
#  ac.uk total count: 707
#  ac.uk # of domains: 170
#  ac.uk mean count per domain: 4.16
#
#                              Domain  resource_domain
# 385                      ebi.ac.uk               72
# 400             data-archive.ac.uk               70
# 497            ukdataservice.ac.uk               56
# 910                      ucl.ac.uk               29
# 928   discover.ukdataservice.ac.uk               28
# 1055               v2.sherpa.ac.uk               25
# 1078               blogs.lse.ac.uk               24
# 1229                     dcc.ac.uk               21
# 1377                     bgs.ac.uk               18
# 1662  archaeologydataservice.ac.uk               15
# ------------------------------------------------
#
# gsu.edu
# ------------------------------------------------
#  gsu.edu total count: 706
#  gsu.edu # of domains: 21
#  gsu.edu mean count per domain: 33.62
#
#                                    Domain  resource_domain
# 23              research.library.gsu.edu              575
# 781              campusdirectory.gsu.edu               34
# 1065               ursa.research.gsu.edu               24
# 1266                  technology.gsu.edu               20
# 1425                policecrime.bgsu.edu               17
# 1529                     gilfind.gsu.edu               16
# 1945  digitalcollections.library.gsu.edu               12
# 2839                     library.gsu.edu                8
# 6578                       acrdc.gsu.edu                3
# 8677             collegetocareer.gsu.edu                2
# ------------------------------------------------
#
# mit.edu
# ------------------------------------------------
#  mit.edu total count: 700
#  mit.edu # of domains: 28
#  mit.edu mean count per domain: 25.00
#
#                        Domain  resource_domain
# 90         libguides.mit.edu              282
# 141        libraries.mit.edu              199
# 463      electionlab.mit.edu               62
# 817          library.mit.edu               33
# 827              web.mit.edu               32
# 1294  login.libproxy.mit.edu               20
# 1315             ocw.mit.edu               19
# 1790      livingwage.mit.edu               13
# 2870           wikis.mit.edu                8
# 3597         geodata.mit.edu                6
# ------------------------------------------------
#
# duke.edu
# ------------------------------------------------
#  duke.edu total count: 692
#  duke.edu # of domains: 40
#  duke.edu mean count per domain: 17.30
#
#                              Domain  resource_domain
# 176          find.library.duke.edu              174
# 193               library.duke.edu              149
# 244        guides.library.duke.edu              118
# 281       login.proxy.lib.duke.edu              103
# 925             proxy.lib.duke.edu               28
# 1297                sites.duke.edu               19
# 1492           db.library.duke.edu               16
# 2285        library.fuqua.duke.edu               10
# 2523  getitatduke.library.duke.edu                9
# 2606       search.library.duke.edu                9
# ------------------------------------------------
#
# imf.org
# ------------------------------------------------
#  imf.org total count: 689
#  imf.org # of domains: 17
#  imf.org mean count per domain: 40.53
#
#                                                 Domain  resource_domain
# 69                                            imf.org              328
# 79                                       data.imf.org              300
# 798                                  elibrary.imf.org               34
# 1209                    data.imf.org.ezp2.lib.umn.edu               21
# 2076                            elibrary-data.imf.org               11
# 2115           data.imf.org.ezp-prod1.hul.harvard.edu               11
# 3766                                 datahelp.imf.org                5
# 4454  elibrary-data.imf.org.ezp-prod1.hul.harvard.edu                4
# 4584                                      fsi.imf.org                4
# 6289                                     dsbb.imf.org                3
# ------------------------------------------------

# %% [markdown]
# ### Top 20 Free and Paid/Hybrid Resources
# The top_dbs_annotated.csv file was created by adding an 'access' column noting whether each of the top 500 resources identified and exported above is 'free', 'paid', or 'hybrid'.

# %%
free_paid_df = pd.read_csv('drum/lg_data_top_annotated.csv')
free_paid_df = free_paid_df.sort_values(by='count', ascending=False)
free_paid_df = free_paid_df.drop(columns=['sum'])

paid_df = free_paid_df[free_paid_df['access'] == 'paid']
free_df = free_paid_df[free_paid_df['access'] == 'free']
hybrid_df = free_paid_df[free_paid_df['access'] == 'hybrid']
paid_hybrid_df = free_paid_df[free_paid_df['access'] != 'free']

print(
    'Percentage of top 500 resources that are paid or hybrid:', 
    '{:.2%}'.format((len(paid_hybrid_df)/len(free_paid_df))),
    '\nNumber that are paid or hybrid:', 
    len(paid_hybrid_df),
    '\n\tPercentage of top 500 resources that are paid:', 
    '{:.2%}'.format((len(paid_df)/len(free_paid_df))),
    '\n\tNumber that are paid:', 
    len(paid_df),
    '\n\tPercentage of top 500 resources that are hybrid:', 
    '{:.2%}'.format((len(hybrid_df)/len(free_paid_df))),
    '\n\tNumber that are hybrid:', 
    len(hybrid_df),
     '\nPercentage of top 500 resources that are free:',               
      '{:.2%}'.format((len(free_df)/len(free_paid_df))), 
    '\nNumber that are free:', 
    len(free_df),
                   )

print(
    '\n\nNumber of links for paid/hybrid resources:', paid_hybrid_df['count'].sum(),
    '\nMean number of links per paid/hybrid resource:', '{:.2f}'.format(paid_hybrid_df['count'].mean()),
    '\n\n\tNumer of links to paid resources:', paid_df['count'].sum(),
    '\n\tMean number of links per paid resource:', '{:.2f}'.format(paid_df['count'].mean()),
    '\n\tMedian number of links per paid resource:', '{:.2f}'.format(paid_df['count'].median()),
    '\n\n\tNumer of links to hybrid resources:', hybrid_df['count'].sum(),
    '\n\tMean number of links per hybrid resource:', '{:.2f}'.format(hybrid_df['count'].mean()),
    '\n\tMedian number of links per hybrid resource:', '{:.2f}'.format(hybrid_df['count'].median()),
    '\n\nNumber of links for free resources:', free_df['count'].sum(),
    '\nMean number of links per free resource:', '{:.2f}'.format(free_df['count'].mean()),
    '\nMedian number of links per free resource:', '{:.2f}'.format(free_df['count'].median())
)
# Out:
# Percentage of top 500 resources that are paid or hybrid: 20.28%
# Number that are paid or hybrid: 101
# 	Percentage of top 500 resources that are paid: 17.47%
# 	Number that are paid: 87
# 	Percentage of top 500 resources that are hybrid: 2.81%
# 	Number that are hybrid: 14
# Percentage of top 500 resources that are free: 79.72%
# Number that are free: 397
#
#
# Number of links for paid/hybrid resources: 19627
# Mean number of links per paid/hybrid resource: 194.33
#
# 	Numer of links to paid resources: 15175
# 	Mean number of links per paid resource: 174.43
# 	Median number of links per paid resource: 66.00
#
# 	Numer of links to hybrid resources: 4452
# 	Mean number of links per hybrid resource: 318.00
# 	Median number of links per hybrid resource: 67.50
#
# Number of links for free resources: 41361
# Mean number of links per free resource: 104.18
# Median number of links per free resource: 53.00

# %%
paid_hybrid_df[0:20]
# Out:
#                                                   name percent_of_sites  \
# 0                                                icpsr           94.31%
# 33                      statistical insight (proquest)           61.79%
# 11                                     social explorer           78.86%
# 51                                  data planet (sage)           50.41%
# 28                                            statista           64.23%
# 10                                 roper center: ipoll           80.49%
# 14   statistical abstract of the united states (pro...           78.05%
# 22                                       oecd ilibrary           69.11%
# 16   historical statistics of the united states (ca...           74.80%
# 66                                     simplyanalytics           44.72%
# 73                                           policymap           43.09%
# 67               wharton research data services (wrds)           43.90%
# 63                                 polling the nations           45.53%
# 103               passport (euromonitor international)           34.96%
# 110                                  china data online           33.33%
# 105                   business source complete (ebsco)           34.15%
# 114     data citation index (web of science/clarivate)           32.52%
# 220                  economist intelligence unit (eiu)           21.14%
# 74                                           ibisworld           43.09%
# 156                                  europa world plus           26.83%
#
#      count                                                url  access
# 0     1834                                www.icpsr.umich.edu  hybrid
# 33    1532  proxy2.library.illinois.edu/login?url=search.p...    paid
# 11    1430                             www.socialexplorer.com    paid
# 51    1318  go.openathens.net/redirector/fiu.edu?url=datap...    paid
# 28    1104  go.openathens.net/redirector/fiu.edu?url=http%...  hybrid
# 10    1090  proxy2.library.illinois.edu/login?url=ropercen...    paid
# 14    1058         www.libraries.rutgers.edu/indexes/statabus    paid
# 22     851                              www.oecd-ilibrary.org  hybrid
# 16     684                         hsus.cambridge.org/HSUSWeb    paid
# 66     672  go.openathens.net/redirector/fiu.edu?url=app.s...    paid
# 73     645                           library.bu.edu/policymap    paid
# 67     470           nrs.harvard.edu/urn-3:hul.eresource:WRDS    paid
# 63     313       nrs.harvard.edu/urn-3:hul.eresource:pollnati    paid
# 103    249  ezproxy.fiu.edu/login?url=www.portal.euromonit...    paid
# 110    209    ezproxy.fiu.edu/login?url=china-data-online.com    paid
# 105    191  search.ebscohost.com/login.aspx?authtype=shib,...    paid
# 114    177                              isiknowledge.com/drci    paid
# 220    175  id.lib.harvard.edu/alma/990081655110203941/cat...    paid
# 74     168        ezproxy.fiu.edu/login?url=www.ibisworld.com    paid
# 156    161                              uclibs.org/PID/115872    paid

# %%
free_df[0:20]
# Out:
#                                                  name percent_of_sites  count  \
# 3                                   u.s. census: data           90.24%   1145
# 4                             undata (united nations)           88.62%   1054
# 2                                  u.s. census bureau           93.50%    956
# 1                                            data.gov           94.31%    954
# 6   nchs (u.s. national center for health statistics)           86.99%    856
# 7                    u.s. census: american factfinder           83.74%    720
# 25           world bank: world development indicators           65.85%    599
# 5   nces (u.s. national center for education stati...           86.99%    546
# 15                                   world bank: data           76.42%    545
# 8               bls (u.s. bureau of labor statistics)           82.93%    535
# 9                      eurostat (european commission)           80.49%    501
# 13  who: global health observatory (world health o...           78.05%    491
# 18             imf data (international monetary fund)           74.80%    445
# 20           u.s. census: statistical abstract series           71.54%    442
# 12            bjs (u.s. bureau of justice statistics)           78.86%    437
# 17             bea (u.s. bureau of economic analysis)           74.80%    422
# 38                                pew research center           60.16%    386
# 21                       usa.gov: data and statistics           69.92%    385
# 19                           cdc: data and statistics           73.17%    361
# 56                               world bank: databank           49.59%    348
#
#                                                   url access
# 3                              data.census.gov/cedsci   free
# 4                                         data.un.org   free
# 2                                      www.census.gov   free
# 1                                        www.data.gov   free
# 6                                    www.cdc.gov/nchs   free
# 7   factfinder.census.gov/faces/nav/jsf/pages/inde...   free
# 25  data.worldbank.org/data-catalog/world-developm...   free
# 5                                         nces.ed.gov   free
# 15                                 data.worldbank.org   free
# 8                                         www.bls.gov   free
# 9                               ec.europa.eu/eurostat   free
# 13                                 www.who.int/gho/en   free
# 18                                       data.imf.org   free
# 20  www.census.gov/library/publications/time-serie...   free
# 12                                        www.bjs.gov   free
# 17                                        www.bea.gov   free
# 38                                www.pewresearch.org   free
# 21                             www.usa.gov/statistics   free
# 19                         www.cdc.gov/DataStatistics   free
# 56              databank.worldbank.org/data/home.aspx   free

# %%
hybrid_df[0:20]
# Out:
#                                                   name percent_of_sites  \
# 0                                                icpsr           94.31%
# 28                                            statista           64.23%
# 22                                       oecd ilibrary           69.11%
# 195                          oecd ilibrary: statistics           22.76%
# 446                              rand state statistics           10.57%
# 130  oecd (organisation for economic co-operation a...           30.08%
# 170                                  pollingreport.com           23.58%
# 184      icpsr: health and medical care archive (hmca)           22.76%
# 447                                       wolframalpha           10.57%
# 497                     byu law and corpus linguistics            0.81%
# 209    icpsr: resource center for minority data (rcmd)           21.14%
# 276  icpsr: national archive of computerized data o...           17.89%
# 344  cpanda (cultural policy and the arts national ...           14.63%
# 292  icpsr: national archive of data on arts and cu...           17.07%
#
#      count                                                url  access
# 0     1834                                www.icpsr.umich.edu  hybrid
# 28    1104  go.openathens.net/redirector/fiu.edu?url=http%...  hybrid
# 22     851                              www.oecd-ilibrary.org  hybrid
# 195    110                   www.oecd-ilibrary.org/statistics  hybrid
# 446     83                             www.randstatestats.org  hybrid
# 130     78                                       www.oecd.org  hybrid
# 170     68                              www.pollingreport.com  hybrid
# 184     67      www.icpsr.umich.edu/web/pages/HMCA/index.html  hybrid
# 447     58                               www.wolframalpha.com  hybrid
# 497     55                                  lawcorpus.byu.edu  hybrid
# 209     42                  www.icpsr.umich.edu/icpsrweb/RCMD  hybrid
# 276     35                 www.icpsr.umich.edu/icpsrweb/NACDA  hybrid
# 344     35                              www.cpanda.org/cpanda  hybrid
# 292     32                 www.icpsr.umich.edu/icpsrweb/NADAC  hybrid

# %% [markdown]
# #### Output the Top 200 resources (annotated as free/paid/hybrid) to HTML Table
# To view the rendered table of 200 top resources online, visit (GitHub pages link forthcoming).

# %%
for_html = free_paid_df.sort_values(by='count', ascending=False)[0:200]

for_html = for_html.reset_index()
for_html.index += 1 
for_html = for_html[['name', 'percent_of_sites', 'count', 'access', 'url']]

html = for_html.to_html()
  
# write html to file
text_file = open("table.html", "w")
text_file.write(html)
text_file.close()
